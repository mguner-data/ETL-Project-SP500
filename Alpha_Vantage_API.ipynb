# %%
# Dependencies and Setup
import requests
import json
import pandas as pd
import os
import time

# Import API key
from api_keys import Alpha_Vantage_Key

# Set Up Query URL
symbol = 'AAL'
query_url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&outputsize=full&apikey={Alpha_Vantage_Key}'

# Output File (CSV)
output_data_file = "Alpha_Vantage_Export.csv"

# %%
#import list of stock tickers to query
file_path = os.path.join('constituents.csv')
current_component_df = pd.read_csv(file_path)
stock_ticker_list = current_component_df['Symbol']

for symbol in stock_ticker_list:
    print(symbol)
print(f'The number of tickers in the list is {len(stock_ticker_list)}')
# Out:
# MMM
# AOS
# ABT
# ABBV
# ABMD
# ACN
# ATVI
# ADBE
# AAP
# AMD
# AES
# AFL
# A
# APD
# AKAM
# ALK
# ALB
# ARE
# ALXN
# ALGN
# ALLE
# LNT
# ALL
# GOOGL
# GOOG
# MO
# AMZN
# AMCR
# AEE
# AAL
# AEP
# AXP
# AIG
# AMT
# AWK
# AMP
# ABC
# AME
# AMGN
# APH
# ADI
# ANSS
# ANTM
# AON
# APA
# AIV
# AAPL
# AMAT
# APTV
# ADM
# ANET
# AJG
# AIZ
# T
# ATO
# ADSK
# ADP
# AZO
# AVB
# AVY
# BKR
# BLL
# BAC
# BAX
# BDX
# BRK.B
# BBY
# BIO
# BIIB
# BLK
# BA
# BKNG
# BWA
# BXP
# BSX
# BMY
# AVGO
# BR
# BF.B
# CHRW
# COG
# CDNS
# CPB
# COF
# CAH
# KMX
# CCL
# CARR
# CAT
# CBOE
# CBRE
# CDW
# CE
# CNC
# CNP
# CTL
# CERN
# CF
# SCHW
# CHTR
# CVX
# CMG
# CB
# CHD
# CI
# CINF
# CTAS
# CSCO
# C
# CFG
# CTXS
# CME
# CMS
# KO
# CTSH
# CL
# CMCSA
# CMA
# CAG
# CXO
# COP
# ED
# STZ
# CPRT
# GLW
# CTVA
# COST
# COTY
# CCI
# CSX
# CMI
# CVS
# DHI
# DHR
# DRI
# DVA
# DE
# DAL
# XRAY
# DVN
# DXCM
# FANG
# DLR
# DFS
# DISCA
# DISCK
# DISH
# DG
# DLTR
# D
# DPZ
# DOV
# DOW
# DTE
# DUK
# DRE
# DD
# DXC
# ETFC
# EMN
# ETN
# EBAY
# ECL
# EIX
# EW
# EA
# EMR
# ETR
# EOG
# EFX
# EQIX
# EQR
# ESS
# EL
# RE
# EVRG
# ES
# EXC
# EXPE
# EXPD
# EXR
# XOM
# FFIV
# FB
# FAST
# FRT
# FDX
# FIS
# FITB
# FRC
# FE
# FISV
# FLT
# FLIR
# FLS
# FMC
# F
# FTNT
# FTV
# FBHS
# FOXA
# FOX
# BEN
# FCX
# GPS
# GRMN
# IT
# GD
# GE
# GIS
# GM
# GPC
# GILD
# GPN
# GL
# GS
# GWW
# HRB
# HAL
# HBI
# HIG
# HAS
# HCA
# PEAK
# HSIC
# HES
# HPE
# HLT
# HFC
# HOLX
# HD
# HON
# HRL
# HST
# HWM
# HPQ
# HUM
# HBAN
# HII
# IEX
# IDXX
# INFO
# ITW
# ILMN
# INCY
# IR
# INTC
# ICE
# IBM
# IFF
# IP
# IPG
# INTU
# ISRG
# IVZ
# IPGP
# IQV
# IRM
# JBHT
# JKHY
# J
# SJM
# JNJ
# JCI
# JPM
# JNPR
# KSU
# K
# KEY
# KEYS
# KMB
# KIM
# KMI
# KLAC
# KSS
# KHC
# KR
# LB
# LHX
# LH
# LRCX
# LW
# LVS
# LEG
# LDOS
# LEN
# LLY
# LNC
# LIN
# LYV
# LKQ
# LMT
# L
# LOW
# LYB
# MTB
# MRO
# MPC
# MKTX
# MAR
# MMC
# MLM
# MAS
# MA
# MXIM
# MKC
# MCD
# MCK
# MDT
# MRK
# MET
# MTD
# MGM
# MCHP
# MU
# MSFT
# MAA
# MHK
# TAP
# MDLZ
# MNST
# MCO
# MS
# MSI
# MSCI
# MYL
# NDAQ
# NOV
# NTAP
# NFLX
# NWL
# NEM
# NWSA
# NWS
# NEE
# NLSN
# NKE
# NI
# NBL
# NSC
# NTRS
# NOC
# NLOK
# NCLH
# NRG
# NUE
# NVDA
# NVR
# ORLY
# OXY
# ODFL
# OMC
# OKE
# ORCL
# OTIS
# PCAR
# PKG
# PH
# PAYX
# PAYC
# PYPL
# PNR
# PBCT
# PEP
# PKI
# PRGO
# PFE
# PM
# PSX
# PNW
# PXD
# PNC
# PPG
# PPL
# PFG
# PG
# PGR
# PLD
# PRU
# PEG
# PSA
# PHM
# PVH
# QRVO
# QCOM
# PWR
# DGX
# RL
# RJF
# RTX
# O
# REG
# REGN
# RF
# RSG
# RMD
# RHI
# ROK
# ROL
# ROP
# ROST
# RCL
# SPGI
# CRM
# SBAC
# SLB
# STX
# SEE
# SRE
# NOW
# SHW
# SPG
# SWKS
# SLG
# SNA
# SO
# LUV
# SWK
# SBUX
# STT
# STE
# SYK
# SIVB
# SYF
# SNPS
# SYY
# TMUS
# TROW
# TTWO
# TPR
# TGT
# TEL
# FTI
# TDY
# TFX
# TXN
# TXT
# BK
# CLX
# COO
# HSY
# MOS
# TRV
# DIS
# TMO
# TIF
# TJX
# TSCO
# TT
# TDG
# TFC
# TWTR
# TYL
# TSN
# USB
# UDR
# ULTA
# UAA
# UA
# UNP
# UAL
# UNH
# UPS
# URI
# UHS
# UNM
# VLO
# VAR
# VTR
# VRSN
# VRSK
# VZ
# VRTX
# VFC
# VIAC
# V
# VNO
# VMC
# WRB
# WAB
# WBA
# WMT
# WM
# WAT
# WEC
# WFC
# WELL
# WST
# WDC
# WU
# WRK
# WY
# WHR
# WMB
# WLTW
# WYNN
# XEL
# XRX
# XLNX
# XYL
# YUM
# ZBRA
# ZBH
# ZION
# ZTS
# The number of tickers in the list is 505

# %%
#set up empty lists, variables and url.
date_list = []
open_list = []
high_list  = []
low_list = []
close_list = []
volume_list = []
name_list = []

# %%
#FOR Loop on stock ticker list
for symbol in stock_ticker_list:
    try:
        #Create API call
        query_url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&outputsize=full&apikey={Alpha_Vantage_Key}'
        stock_data = requests.get(query_url).json()
        #Create list of avaliable dates
        list_of_dates = stock_data["Time Series (Daily)"].keys()
        #FOR loop through dates for this symbol
        for lookup_date in list_of_dates:
            date_list.append(lookup_date)
            open_list.append(stock_data["Time Series (Daily)"][lookup_date]['1. open'])
            high_list.append(stock_data["Time Series (Daily)"][lookup_date]['2. high'])
            low_list.append(stock_data["Time Series (Daily)"][lookup_date]['3. low'])
            close_list.append(stock_data["Time Series (Daily)"][lookup_date]['4. close'])
            volume_list.append(stock_data["Time Series (Daily)"][lookup_date]['4. close'])
            name_list.append(symbol)
        print(f'{symbol} successfully added')
    except KeyError:
        #If there's a KeyError, it's likely because we've queried the API too quickly, so wait.
        try:
            query_url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&outputsize=full&apikey={Alpha_Vantage_Key}'
            print(f'{symbol} does not exist')
            print("Waiting....")
            time.sleep(60)
            #Create API call
            query_url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={symbol}&outputsize=full&apikey={Alpha_Vantage_Key}'
            stock_data = requests.get(query_url).json()
            #Create list of avaliable dates
            list_of_dates = stock_data["Time Series (Daily)"].keys()
            #FOR loop through dates for this symbol
            for lookup_date in list_of_dates:
                date_list.append(lookup_date)
                open_list.append(stock_data["Time Series (Daily)"][lookup_date]['1. open'])
                high_list.append(stock_data["Time Series (Daily)"][lookup_date]['2. high'])
                low_list.append(stock_data["Time Series (Daily)"][lookup_date]['3. low'])
                close_list.append(stock_data["Time Series (Daily)"][lookup_date]['4. close'])
                volume_list.append(stock_data["Time Series (Daily)"][lookup_date]['4. close'])
                name_list.append(symbol)
            print(f'{symbol} successfully added')
        except KeyError:
            print(f'{symbol} does not exist even after waiting')
# Out:
# MMM successfully added
# AOS successfully added
# ABT successfully added
# ABBV successfully added
# ABMD successfully added
# ACN does not exist
# Waiting....
# ACN successfully added
# ATVI successfully added
# ADBE successfully added
# AAP successfully added
# AMD successfully added
# AES does not exist
# Waiting....
# AES successfully added
# AFL successfully added
# A successfully added
# APD successfully added
# AKAM successfully added
# ALK does not exist
# Waiting....
# ALK successfully added
# ALB successfully added
# ARE successfully added
# ALXN successfully added
# ALGN successfully added
# ALLE does not exist
# Waiting....
# ALLE successfully added
# LNT successfully added
# ALL successfully added
# GOOGL successfully added
# GOOG successfully added
# MO does not exist
# Waiting....
# MO successfully added
# AMZN successfully added
# AMCR successfully added
# AEE successfully added
# AAL successfully added
# AEP successfully added
# AXP successfully added
# AIG does not exist
# Waiting....
# AIG successfully added
# AMT successfully added
# AWK successfully added
# AMP successfully added
# ABC successfully added
# AME does not exist
# Waiting....
# AME successfully added
# AMGN successfully added
# APH successfully added
# ADI successfully added
# ANSS successfully added
# ANTM does not exist
# Waiting....
# ANTM successfully added
# AON successfully added
# APA successfully added
# AIV successfully added
# AAPL successfully added
# AMAT does not exist
# Waiting....
# AMAT successfully added
# APTV successfully added
# ADM successfully added
# ANET successfully added
# AJG successfully added
# AIZ does not exist
# Waiting....
# AIZ successfully added
# T successfully added
# ATO successfully added
# ADSK successfully added
# ADP successfully added
# AZO does not exist
# Waiting....
# AZO successfully added
# AVB successfully added
# AVY successfully added
# BKR successfully added
# BLL successfully added
# BAC does not exist
# Waiting....
# BAC successfully added
# BAX successfully added
# BDX successfully added
# BRK.B successfully added
# BBY successfully added
# BIO does not exist
# Waiting....
# BIO successfully added
# BIIB successfully added
# BLK successfully added
# BA successfully added
# BKNG successfully added
# BWA successfully added
# BXP successfully added
# BSX successfully added
# BMY successfully added
# AVGO successfully added
# BR successfully added
# BF.B does not exist
# Waiting....
# BF.B does not exist even after waiting
# CHRW successfully added
# COG successfully added
# CDNS successfully added
# CPB successfully added
# COF does not exist
# Waiting....
# COF successfully added
# CAH successfully added
# KMX successfully added
# CCL successfully added
# CARR successfully added
# CAT does not exist
# Waiting....
# CAT successfully added
# CBOE successfully added
# CBRE successfully added
# CDW successfully added
# CE successfully added
# CNC does not exist
# Waiting....
# CNC successfully added
# CNP successfully added
# CTL successfully added
# CERN successfully added
# CF successfully added
# SCHW does not exist
# Waiting....
# SCHW successfully added
# CHTR successfully added
# CVX successfully added
# CMG successfully added
# CB successfully added
# CHD does not exist
# Waiting....
# CHD successfully added
# C successfully added
# CFG successfully added
# CTXS successfully added
# CME successfully added
# CMS successfully added
# KO does not exist
# Waiting....
# KO successfully added
# CTSH successfully added
# CL successfully added
# CMCSA successfully added
# CMA successfully added
# CAG does not exist
# Waiting....
# CAG successfully added
# CXO successfully added
# COP successfully added
# ED successfully added
# STZ successfully added
# CPRT successfully added
# GLW does not exist
# Waiting....
# GLW successfully added
# CTVA successfully added
# COST successfully added
# COTY successfully added
# CCI successfully added
# CSX does not exist
# Waiting....
# CSX successfully added
# CMI successfully added
# CVS successfully added
# DHI successfully added
# DHR successfully added
# DRI does not exist
# Waiting....
# DRI successfully added
# DVA successfully added
# DE successfully added
# DAL successfully added
# XRAY successfully added
# DVN does not exist
# Waiting....
# DVN successfully added
# DXCM successfully added
# FANG successfully added
# DLR successfully added
# DFS successfully added
# DISCA does not exist
# Waiting....
# DISCA successfully added
# DISCK successfully added
# DISH successfully added
# DG successfully added
# DLTR successfully added
# D does not exist
# Waiting....
# D successfully added
# DPZ successfully added
# DOV successfully added
# DOW successfully added
# DTE successfully added
# DUK does not exist
# Waiting....
# DUK successfully added
# DRE successfully added
# DD successfully added
# DXC successfully added
# ETFC successfully added
# EMN does not exist
# Waiting....
# EMN successfully added
# ETN successfully added
# EBAY successfully added
# ECL successfully added
# EIX successfully added
# EW does not exist
# Waiting....
# EW successfully added
# EA successfully added
# EMR successfully added
# ETR successfully added
# EOG successfully added
# EFX successfully added
# EQIX successfully added
# EQR successfully added
# ESS does not exist
# Waiting....
# ESS successfully added
# EL successfully added
# RE successfully added
# EVRG successfully added
# ES successfully added
# EXC does not exist
# Waiting....
# EXC successfully added
# EXPE successfully added
# EXPD successfully added
# EXR successfully added
# XOM successfully added
# FFIV does not exist
# Waiting....
# FFIV successfully added
# FB successfully added
# FAST successfully added
# FRT successfully added
# FDX successfully added
# FIS does not exist
# Waiting....
# FIS successfully added
# FITB successfully added
# FRC successfully added
# FE successfully added
# FISV successfully added
# FLT does not exist
# Waiting....
# FLT successfully added
# FLIR successfully added
# FLS successfully added
# FMC successfully added
# F successfully added
# FTNT does not exist
# Waiting....
# FTNT successfully added
# FTV successfully added
# FBHS successfully added
# FOXA successfully added
# FOX successfully added
# BEN does not exist
# Waiting....
# BEN successfully added
# FCX successfully added
# GPS successfully added
# GRMN successfully added
# IT successfully added
# GD does not exist
# Waiting....
# GD successfully added
# GE successfully added
# GIS successfully added
# GM successfully added
# GPC successfully added
# GILD does not exist
# Waiting....
# GILD successfully added
# GPN successfully added
# GL successfully added
# GS successfully added
# GWW successfully added
# HRB successfully added
# HAL successfully added
# HBI successfully added
# HIG successfully added
# HAS does not exist
# Waiting....
# HAS successfully added
# HCA successfully added
# PEAK successfully added
# HSIC successfully added
# HES successfully added
# HPE does not exist
# Waiting....
# HPE successfully added
# HLT successfully added
# HFC successfully added
# HOLX successfully added
# HD successfully added
# HON does not exist
# Waiting....
# HON successfully added
# HRL successfully added
# HST successfully added
# HWM successfully added
# HPQ successfully added
# HUM does not exist
# Waiting....
# HUM successfully added
# HBAN successfully added
# HII successfully added
# IEX successfully added
# IDXX successfully added
# INFO does not exist
# Waiting....
# INFO successfully added
# ITW successfully added
# ILMN successfully added
# INCY successfully added
# IR successfully added
# INTC does not exist
# Waiting....
# INTC successfully added
# ICE successfully added
# IBM successfully added
# IFF successfully added
# IP successfully added
# IPG does not exist
# Waiting....
# IPG successfully added
# INTU successfully added
# ISRG successfully added
# IVZ successfully added
# IPGP successfully added
# IQV does not exist
# Waiting....
# IQV successfully added
# IRM successfully added
# JBHT successfully added
# JKHY successfully added
# J successfully added
# SJM does not exist
# Waiting....
# SJM successfully added
# JNJ successfully added
# JCI successfully added
# JPM successfully added
# JNPR successfully added
# KSU successfully added
# K successfully added
# KEY does not exist
# Waiting....
# KEY successfully added
# KEYS successfully added
# KMB successfully added
# KIM successfully added
# KMI successfully added
# KLAC does not exist
# Waiting....
# KLAC successfully added
# KSS successfully added
# KHC successfully added
# KR successfully added
# LB successfully added
# LHX does not exist
# Waiting....
# LHX successfully added
# LH successfully added
# LRCX successfully added
# LW successfully added
# LVS successfully added
# LEG does not exist
# Waiting....
# LEG successfully added
# LDOS successfully added
# LEN successfully added
# LLY successfully added
# LNC successfully added
# LIN does not exist
# Waiting....
# LIN successfully added
# LYV successfully added
# LKQ successfully added
# LMT successfully added
# L successfully added
# LOW does not exist
# Waiting....
# LOW successfully added
# LYB successfully added
# MTB successfully added
# MRO successfully added
# MPC successfully added
# MKTX does not exist
# Waiting....
# MKTX successfully added
# MAR successfully added
# MMC successfully added
# MLM successfully added
# MAS successfully added
# MA does not exist
# Waiting....
# MA successfully added
# MXIM successfully added
# MKC successfully added
# MCD successfully added
# MCK successfully added
# MDT does not exist
# Waiting....
# MDT successfully added
# MRK successfully added
# MET successfully added
# MTD successfully added
# MGM successfully added
# MCHP successfully added
# MU does not exist
# Waiting....
# MU successfully added
# MSFT successfully added
# MAA successfully added
# MHK successfully added
# TAP successfully added
# MDLZ does not exist
# Waiting....
# MDLZ successfully added
# MNST successfully added
# MCO successfully added
# MS successfully added
# MSI successfully added
# MSCI does not exist
# Waiting....
# MSCI successfully added
# MYL successfully added
# NDAQ successfully added
# NOV successfully added
# NTAP successfully added
# NFLX does not exist
# Waiting....
# NFLX successfully added
# NWL successfully added
# NEM successfully added
# NWSA successfully added
# NWS successfully added
# NEE does not exist
# Waiting....
# NEE successfully added
# NLSN successfully added
# NKE successfully added
# NI successfully added
# NBL successfully added
# NSC does not exist
# Waiting....
# NSC successfully added
# NTRS successfully added
# NOC successfully added
# NLOK successfully added
# NCLH successfully added
# NRG does not exist
# Waiting....
# NRG successfully added
# NUE successfully added
# NVDA successfully added
# NVR successfully added
# ORLY successfully added
# OXY does not exist
# Waiting....
# OXY successfully added
# PAYC successfully added
# PYPL successfully added
# PNR successfully added
# PBCT successfully added
# PEP successfully added
# PKI does not exist
# Waiting....
# PKI successfully added
# PRGO successfully added
# PFE successfully added
# PM successfully added
# PSX successfully added
# PNW does not exist
# Waiting....
# PNW successfully added
# PXD successfully added
# PNC successfully added
# PPG successfully added
# PPL successfully added
# PFG does not exist
# Waiting....
# PFG successfully added
# PG successfully added
# PGR successfully added
# PLD successfully added
# PRU successfully added
# PEG does not exist
# Waiting....
# PEG successfully added
# PSA successfully added
# PHM successfully added
# PVH successfully added
# QRVO successfully added
# QCOM does not exist
# Waiting....
# QCOM successfully added
# PWR successfully added
# DGX successfully added
# RL successfully added
# RJF successfully added
# RTX does not exist
# Waiting....
# RTX successfully added
# O successfully added
# REG successfully added
# REGN successfully added
# RF successfully added
# RSG does not exist
# Waiting....
# RSG successfully added
# RMD successfully added
# RHI successfully added
# ROK successfully added
# ROL successfully added
# ROP does not exist
# Waiting....
# ROP successfully added
# ROST successfully added
# RCL successfully added
# SPGI successfully added
# CRM successfully added
# SBAC successfully added
# SLB successfully added
# STX does not exist
# Waiting....
# STX successfully added
# SEE successfully added
# SRE successfully added
# NOW successfully added
# SHW successfully added
# SPG does not exist
# Waiting....
# SPG successfully added
# SWKS successfully added
# SLG successfully added
# SNA successfully added
# SO successfully added
# LUV does not exist
# Waiting....
# LUV successfully added
# SWK successfully added
# SBUX successfully added
# STT successfully added
# STE successfully added
# SYK does not exist
# Waiting....
# SYK successfully added
# SIVB successfully added
# SYF successfully added
# SNPS successfully added
# SYY successfully added
# TMUS does not exist
# Waiting....
# TMUS successfully added
# TROW successfully added
# TTWO successfully added
# TPR successfully added
# TGT successfully added
# TEL does not exist
# Waiting....
# TEL successfully added
# FTI successfully added
# TDY successfully added
# TFX successfully added
# TXN successfully added
# TXT does not exist
# Waiting....
# TXT successfully added
# BK successfully added
# CLX successfully added
# COO successfully added
# HSY successfully added
# MOS does not exist
# Waiting....
# MOS successfully added
# TDG successfully added
# TFC successfully added
# TWTR successfully added
# TYL successfully added
# TSN successfully added
# USB does not exist
# Waiting....
# USB successfully added
# UDR successfully added
# ULTA successfully added
# UAA successfully added
# UA successfully added
# UNP does not exist
# Waiting....
# UNP successfully added
# UAL successfully added
# UNH successfully added
# UPS successfully added
# URI successfully added
# UHS does not exist
# Waiting....
# UHS successfully added
# UNM successfully added
# VLO successfully added
# VAR successfully added
# VTR successfully added
# VRSN does not exist
# Waiting....
# VRSN successfully added
# VRSK successfully added
# VZ successfully added
# VRTX successfully added
# VFC successfully added
# VIAC does not exist
# Waiting....
# VIAC successfully added
# V successfully added
# VNO successfully added
# VMC successfully added
# WRB successfully added
# WAB does not exist
# Waiting....
# WAB successfully added
# WBA successfully added
# WMT successfully added
# WM successfully added
# WAT successfully added
# WEC does not exist
# Waiting....
# WEC successfully added
# WFC successfully added
# WELL successfully added
# WST successfully added
# WDC successfully added
# WU does not exist
# Waiting....
# WU successfully added
# WRK successfully added
# WY successfully added
# WHR successfully added
# WMB successfully added
# WLTW successfully added
# WYNN successfully added
# XEL does not exist
# Waiting....
# XEL successfully added
# XRX successfully added
# XLNX successfully added
# XYL successfully added
# YUM successfully added
# ZBRA does not exist
# Waiting....
# ZBRA successfully added
# ZBH successfully added
# ZION successfully added
# ZTS successfully added

# %%
#set up and populate a dataframe.
all_stocks_df = pd.DataFrame({"date":date_list,
"open":open_list,
"high":high_list,
"low":low_list,
"close":close_list,
"volume":volume_list,
"name":name_list})
all_stocks_df.tail()
# Out:
#                date     open     high      low    close   volume name
# 2326172  2013-02-07  31.0000  32.7300  31.0000  32.0000  32.0000  ZTS
# 2326173  2013-02-06  30.9800  31.4300  30.7500  31.0300  31.0300  ZTS
# 2326174  2013-02-05  31.2500  31.9800  30.8500  31.0400  31.0400  ZTS
# 2326175  2013-02-04  31.0900  31.9900  30.7600  31.0200  31.0200  ZTS
# 2326176  2013-02-01  31.5000  31.7400  30.4700  31.0100  31.0100  ZTS

# %%
#export dataframe to csv
all_stocks_df.to_csv(output_data_file, index=True, header=True)

# %%
print(all_stocks_df.describe(include='all'))
# Out:
#               date     open     high      low    close   volume     name
# count      2326177  2326177  2326177  2326177  2326177  2326177  2326177
# unique        5221    65795   123186   126082    67860    67860      504
# top     2020-03-20  35.0000  35.0000  35.0000  35.0000  35.0000      WAB
# freq           504     1562     1262     1110      973      973     5221
