# %%
import pandas as pd
from sqlalchemy import create_engine
from secret import username, password
import matplotlib.pyplot as plt

# %%
connection_string = f'{username}:{password}@localhost:5432/Stock_DB'
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['ticker_security', 'index_event', 'daily_data']

# %%
df= pd.read_sql_table('daily_data',engine)

# %%
ticker1='AAPL'
ticker2='MSFT'
dfa = df[df['ticker']==ticker1]
dfm = df[df['ticker']==ticker2]
plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size': 22})
plt.plot(dfa['date_close'],dfa['close'],label=ticker1)
plt.plot(dfm['date_close'],dfm['close'],label=ticker2)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ticker1='AAPL'
ticker2='MSFT'
dfa = df[df['ticker']==ticker1]
dfm = df[df['ticker']==ticker2]
plt.figure(figsize=(20,10))
plt.rcParams.update({'font.size': 22})
#plt.plot(dfa['date_close'],dfa['close'],label=ticker1)
plt.plot(dfm['date_close'],dfm['close'],label=ticker2)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
dfa
# Out:
#          index ticker date_close   open     high    low  close  volume
# 171856  171857   AAPL 2020-07-30  11.22  11.3900  11.12  11.18      11
# 171857  171858   AAPL 2020-07-29  11.80  11.9200  11.30  11.40      11
# 171858  171859   AAPL 2020-07-28  11.37  11.9950  11.36  11.77      12
# 171859  171860   AAPL 2020-07-27  11.48  11.7938  11.18  11.39      11
# 171860  171861   AAPL 2020-07-24  11.67  11.8200  11.34  11.39      11
# ...        ...    ...        ...    ...      ...    ...    ...     ...
# 175587  175588   AAPL 2005-10-03  20.90  21.7500  20.90  21.50      22
# 175588  175589   AAPL 2005-09-30  20.26  21.0500  20.18  21.01      21
# 175589  175590   AAPL 2005-09-29  20.40  20.5800  20.10  20.21      20
# 175590  175591   AAPL 2005-09-28  19.30  20.5300  19.20  20.50      21
# 175591  175592   AAPL 2005-09-27  21.05  21.4000  19.10  19.30      19
#
# [3736 rows x 8 columns]

# %%
dfm
# Out:
#            index ticker date_close   open     high    low  close  volume
# 1176840  1176841   MSFT 2020-07-30  11.22  11.3900  11.12  11.18      11
# 1176841  1176842   MSFT 2020-07-29  11.80  11.9200  11.30  11.40      11
# 1176842  1176843   MSFT 2020-07-28  11.37  11.9950  11.36  11.77      12
# 1176843  1176844   MSFT 2020-07-27  11.48  11.7938  11.18  11.39      11
# 1176844  1176845   MSFT 2020-07-24  11.67  11.8200  11.34  11.39      11
# ...          ...    ...        ...    ...      ...    ...    ...     ...
# 1180571  1180572   MSFT 2005-10-03  20.90  21.7500  20.90  21.50      22
# 1180572  1180573   MSFT 2005-09-30  20.26  21.0500  20.18  21.01      21
# 1180573  1180574   MSFT 2005-09-29  20.40  20.5800  20.10  20.21      20
# 1180574  1180575   MSFT 2005-09-28  19.30  20.5300  19.20  20.50      21
# 1180575  1180576   MSFT 2005-09-27  21.05  21.4000  19.10  19.30      19
#
# [3736 rows x 8 columns]
